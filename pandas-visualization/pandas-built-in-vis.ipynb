# %%
import numpy as np 
import pandas as pd 
# %matplotlib inline
import seaborn as sns

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
#note that this data is a time series (first column shows dates)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
#histogram of values in column a of df1
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
#make histogram off of a dataframe of data
df1['A'].plot(kind='hist', bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#instead of kind, you can use hist off of plot
df1['A'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#area plot-similar to a normal line plot, but underneath it is colored
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1.plot.line(x=df1.index,y='B',figsize=(12,3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-9779bd9f885c> in <module>
# ----> 1 df1.plot.line(x=df1.index,y='B',figsize=(12,3))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1015         as coordinates.
#    1016         """
# -> 1017         return self(kind="line", x=x, y=y, **kwargs)
#    1018
#    1019     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     912                 if is_integer(x) and not data.columns.holds_integer():
#     913                     x = data_cols[x]
# --> 914                 elif not isinstance(data[x], ABCSeries):
#     915                     raise ValueError("x must be a label or position")
#     916                 data = data.set_index(x)
#
# ...

# %%
#create a scatter plot with column A as the x axis and column B on the y axis. Use the s argument to change the size of the values based off of the values of C
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# C:\Users\jelia\anaconda3\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
#box plot
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a', 'b'])

# %%
#similar to a scatter plot, but they are hexagons
#gridsize is used to increase the size of the shapes. The darker the shape, the most points that are in that area
df.plot.hexbin(x='a', y='b', gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
#kernel density dataframe
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
